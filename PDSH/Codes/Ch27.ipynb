# %%
print("""
@Description: Simple Scatter Plots
@Author:Stephen CUI
@Time: 2023-04-06 17:31:49
""")
# Out:
# @Description: Simple Scatter Plots
# @Author:Stephen CUI
# @Time: 2023-04-06 17:31:49

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Simple Scatter Plots

# %% [markdown]
# ## Scatter Plots with plt.plot

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

# %%
rng = np.random.default_rng(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.random(size=2), rng.random(size=2), marker,
             label='marker={}'.format(marker))
plt.legend(numpoints=1, fontsize=13)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %%
plt.plot(x, y, '-ok')

# %%
plt.plot(x, y, '-p', color='gray', 
         markersize=10, 
         linewidth=3,
         markerfacecolor='red',
         markeredgecolor='green',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ## Scatter Plots with plt.scatter

# %%
plt.scatter(x, y, marker='o')

# %%
rng = np.random.default_rng(0)
x = rng.normal(size=100)
y = rng.normal(size=100)
colors = rng.random(100)
sizes = 1000 * rng.random(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=.3)
# 个人觉得显示 colorbar 的意义不大
plt.colorbar()

# %%
x = np.linspace(0, 10, 50)
dy = .8
y = np.sin(x) + dy * np.random.randn(50)

# %%
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Continuous Errors

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

gp = GaussianProcessRegressor()
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, dyfit = gp.predict(xfit[:, np.newaxis], return_std=True)

# %%
plt.plot(xdata, ydata, 'o')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit - dyfit, yfit + dyfit, color='gray', alpha=.2)
plt.xlim(0, 10)
# Out:
# (0.0, 10.0)
