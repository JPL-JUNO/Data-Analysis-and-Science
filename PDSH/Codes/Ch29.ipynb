# %%
print("""
@Description: Customizing Plot Legends
@Author:Stephen CUI
@Time: 2023-04-07 09:59:36
""")
# Out:
# @Description: Customizing Plot Legends
# @Author:Stephen CUI
# @Time: 2023-04-07 09:59:36

# %% [markdown]
# # Customizing Plot Legends

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend()

# %%
ax.legend(loc="upper left", frameon=False)
fig

# %%
ax.legend(loc="lower center", ncol=2)
fig

# %%
ax.legend(frameon=True, fancybox=True, framealpha=1,
          shadow=True, borderpad=1, ncol=2, loc='lower center')
fig

# %% [markdown]
# ## Choosing Elements for the Legend

# %%
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, .5))

lines = plt.plot(x, y)
plt.legend(lines[:2], ['first', 'second'], frameon=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(x, y[:, 0], label='first')
plt.plot(x, y[:, 1], label='second')
plt.plot(x, y[:, 2:])
plt.legend()

# %%
import pandas as pd
cities = pd.read_csv('data/california_cities.csv')
lat, lon = cities['latd'], cities['longd']

population, area = cities['population_total'], cities['area_total_km2']

plt.scatter(lon, lat, label=None, c=np.log10(population),cmap='viridis',
            s=area, linewidth=0, alpha=.5)
plt.axis('equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(-3, 7)

for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=.3, s=   , label=str(area)+' km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1.5, title='City Area')
plt.title('California Cities: Area and Population')
plt.show()

# %% [markdown]
# ## Multiple Legends

# %%
fig, ax = plt.subplots()
lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)
for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2),
                     styles[i], color='black')
ax.legend(lines[:2], ['line A', 'line B'], loc='upper right')


ax.axis('equal')

from matplotlib.legend import Legend
leg = Legend(ax, lines[2:], ['line C', 'line D'], loc='lower right')
ax.add_artist(leg)
