# %%
from configparser import ConfigParser
cfg = ConfigParser()

# %%
cfg.read('token.ini')
# Out:
# ['token.ini']

# %%
token = cfg.get("tushare", "token")

# %%
from configparser import ConfigParser
cfg = ConfigParser()
cfg.read('token.ini')
token = cfg.get("tushare", "token")
import tushare as ts
ts.set_token(token)
pro = ts.pro_api(token)
df = pro.daily(ts_code="000001.SZ", start_date="20180701", end_date="20180718")

# %%
df = pro.daily(ts_code="000001.SZ", start_date="20180701", end_date="20180718").set_index("trade_date")
df
# Out:
#               ts_code  open  high   low  close  pre_close  change  pct_chg  \
# trade_date
# 20180718    000001.SZ  8.75  8.85  8.69   8.70       8.72   -0.02    -0.23
# 20180717    000001.SZ  8.74  8.75  8.66   8.72       8.73   -0.01    -0.11
# 20180716    000001.SZ  8.85  8.90  8.69   8.73       8.88   -0.15    -1.69
# 20180713    000001.SZ  8.92  8.94  8.82   8.88       8.88    0.00     0.00
# 20180712    000001.SZ  8.60  8.97  8.58   8.88       8.64    0.24     2.78
# 20180711    000001.SZ  8.76  8.83  8.68   8.78       8.98   -0.20    -2.23
# 20180710    000001.SZ  9.02  9.02  8.89   8.98       9.03   -0.05    -0.55
# 20180709    000001.SZ  8.69  9.03  8.68   9.03       8.66    0.37     4.27
# 20180706    000001.SZ  8.61  8.78  8.45   8.66       8.60    0.06     0.70
# 20180705    000001.SZ  8.62  8.73  8.55   8.60       8.61   -0.01    -0.12
# 20180704    000001.SZ  8.63  8.75  8.61   8.61       8.67   -0.06    -0.69
# ...

# %%
df = pro.daily(ts_code="000300.CSI", start_date="20180701", end_date="20180718")
df
# Out:
# Empty DataFrame
# Columns: [ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount]
# Index: []
