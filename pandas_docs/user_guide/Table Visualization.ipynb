# %%
print("""
@File         : Table Visualization.ipynb
@Author(s)    : Stephen CUI
@LastEditor(s): Stephen CUI
@CreatedTime  : 2024-01-29 19:16:38
@Email        : cuixuanstephen@gmail.com
@Description  : 
""")
# Out:
# @File         : Table Visualization.ipynb
# @Author(s)    : Stephen CUI
# @LastEditor(s): Stephen CUI
# @CreatedTime  : 2024-01-29 19:16:38
# @Email        : cuixuanstephen@gmail.com
# @Description  :

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Formatting the Display

# %% [markdown]
# 使用 `Styler` 操作显示是一项有用的功能，因为可以为其他目的维护索引和数据值提供更好的控制。不必覆盖 `DataFrame` 即可按照喜欢的方式显示它。

# %%
weather_df = pd.DataFrame(
    np.random.rand(10, 2) * 5,
    index=pd.date_range(start="2021-01-01", periods=10),
    columns=["Tokyo", "Beijing"],
)


def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_pretty(styler):
    styler.set_caption("Weather Conditions")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap='YlGnBu')
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  0.183693  1.807550
# 2021-01-02  4.254492  4.578946
# 2021-01-03  2.666541  1.178720
# 2021-01-04  1.890841  3.237639
# 2021-01-05  3.425302  2.352733
# 2021-01-06  3.517742  2.610334
# 2021-01-07  2.699073  3.762311
# 2021-01-08  0.385958  3.792741
# 2021-01-09  4.473581  0.712390
# 2021-01-10  3.444049  4.496181

# %%
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty).to_html('test.html')

# %% [markdown]
# ## 添加样式的方法

# %% [markdown]
# 将自定义 CSS 样式添加到 `Styler` 的主要方法有 3 种：
#
# 1. 使用 `.set_table_styles()` 通过指定的内部 CSS 控制表格的更广泛区域。尽管表格样式允许灵活地添加控制表格所有各个部分的 CSS 选择器和属性，但它们对于单个单元格规范来说并不实用。另请注意，表格样式无法导出到 Excel。
# 2. 使用 `.set_td_classes()` 将外部 CSS 类直接链接到数据单元格，或链接由 `.set_table_styles()` 创建的内部 CSS 类。看这里。这些不能用于列标题行或索引，也不能导出到 Excel。
# 3. 使用 `.apply()` 和 `.map()` 函数将直接内部 CSS 添加到特定数据单元格。从 v1.4.0 开始，还有直接作用于列标题行或索引的方法；`.apply_index()` 和 `.map_index()`。请注意，只有这些方法添加将导出到 Excel 的样式。这些方法的工作方式与 `DataFrame.apply()` 和 `DataFrame.map()` 类似。

# %% [markdown]
# ## 表格样式
#
# 表格样式足够灵活，可以控制表格的所有各个部分，包括列标题和索引。但是，它们对于单个数据单元格或任何类型的条件格式的键入可能很笨拙，因此我们建议将表格样式用于广泛的样式，例如一次整行或整列。

# %% [markdown]
# ## `Styler` Functions

# %% [markdown]
# ### 根据数据采取行动
#
# 我们使用以下方法来传递您的样式函数。这两个方法都采用一个函数（以及其他一些关键字参数）并以某种方式将其应用到 `DataFrame`，从而呈现 CSS 样式。
#
# - `.map()`（按元素）：接受一个函数，该函数采用单个值并返回带有 CSS 属性-值对的字符串。
#
# - `.apply()`（按列/行/表）：接受一个函数，该函数采用 Series 或 DataFrame 并返回具有相同形状的 Series、DataFrame 或 numpy 数组，其中每个元素都是具有 CSS 属性的字符串 -值对。此方法一次传递 DataFrame 的每一列或行，或一次传递整个表，具体取决于 `axis` 关键字参数。对于按列使用 `axis=0`、按行使用 `axis=1` 以及对于整个表一次使用 `axis=None`。

# %% [markdown]
# <div class="alert alert-warning">
#     <strong>警告！</strong>如果你使用的不是 2.X 的 pandas，那么需要使用 applymap()，而不是 map()。
# </div>

# %%
np.random.seed(0)
df2 = pd.DataFrame(np.random.randn(10,4), columns=['A','B','C','D'])
df2.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_72e4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72e4b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_72e4b_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_72e4b_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_72e4b_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72e4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72e4b_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_72e4b_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_72e4b_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_72e4b_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72e4b_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_72e4b_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_72e4b_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_72e4b_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72e4b_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_72e4b_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_72e4b_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_72e4b_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72e4b_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_72e4b_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_72e4b_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_72e4b_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72e4b_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_72e4b_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_72e4b_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_72e4b_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72e4b_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_72e4b_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_72e4b_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_72e4b_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72e4b_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_72e4b_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_72e4b_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_72e4b_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72e4b_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_72e4b_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_72e4b_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_72e4b_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_72e4b_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_72e4b_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_72e4b_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_72e4b_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_72e4b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_72e4b_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_72e4b_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_72e4b_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_72e4b_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
s2 = (
    df2.style
    .applymap(style_negative, props='color:red;')
    .applymap(lambda v: 'opacity: 20%;' if (v < .3) and (v > -.3) else None)
)
s2
# Out:
# <style type="text/css">
# #T_b3c93_row1_col1, #T_b3c93_row4_col3, #T_b3c93_row5_col0, #T_b3c93_row5_col3, #T_b3c93_row6_col1, #T_b3c93_row8_col0, #T_b3c93_row8_col1, #T_b3c93_row8_col2, #T_b3c93_row9_col2, #T_b3c93_row9_col3 {
#   color: red;
# }
# #T_b3c93_row1_col3, #T_b3c93_row2_col0, #T_b3c93_row4_col1, #T_b3c93_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_b3c93_row2_col2, #T_b3c93_row3_col1, #T_b3c93_row6_col2, #T_b3c93_row7_col2, #T_b3c93_row8_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_b3c93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3c93_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b3c93_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b3c93_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b3c93_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3c93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3c93_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_b3c93_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_b3c93_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_b3c93_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3c93_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_b3c93_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_b3c93_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_b3c93_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3c93_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_b3c93_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_b3c93_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_b3c93_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3c93_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_b3c93_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_b3c93_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_b3c93_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3c93_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_b3c93_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_b3c93_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_b3c93_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3c93_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_b3c93_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_b3c93_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_b3c93_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3c93_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_b3c93_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_b3c93_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_b3c93_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3c93_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_b3c93_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_b3c93_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_b3c93_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3c93_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_b3c93_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_b3c93_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_b3c93_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3c93_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_b3c93_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_b3c93_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_b3c93_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
(
    df2.style
    .applymap(lambda v: 'opacity: 90%; color: black;')
    .applymap(lambda v: 'background: #bbb666;' if (v < 0) else 'background:#666fff;')
)
# Out:
# <style type="text/css">
# #T_dea75_row0_col0, #T_dea75_row0_col1, #T_dea75_row0_col2, #T_dea75_row0_col3, #T_dea75_row1_col0, #T_dea75_row1_col2, #T_dea75_row2_col1, #T_dea75_row2_col2, #T_dea75_row2_col3, #T_dea75_row3_col0, #T_dea75_row3_col1, #T_dea75_row3_col2, #T_dea75_row3_col3, #T_dea75_row4_col0, #T_dea75_row4_col2, #T_dea75_row5_col1, #T_dea75_row5_col2, #T_dea75_row6_col0, #T_dea75_row6_col2, #T_dea75_row7_col0, #T_dea75_row7_col1, #T_dea75_row7_col2, #T_dea75_row7_col3, #T_dea75_row8_col3, #T_dea75_row9_col0, #T_dea75_row9_col1 {
#   opacity: 90%;
#   color: black;
#   background: #666fff;
# }
# #T_dea75_row1_col1, #T_dea75_row1_col3, #T_dea75_row2_col0, #T_dea75_row4_col1, #T_dea75_row4_col3, #T_dea75_row5_col0, #T_dea75_row5_col3, #T_dea75_row6_col1, #T_dea75_row6_col3, #T_dea75_row8_col0, #T_dea75_row8_col1, #T_dea75_row8_col2, #T_dea75_row9_col2, #T_dea75_row9_col3 {
#   opacity: 90%;
#   color: black;
#   background: #bbb666;
# }
# </style>
# <table id="T_dea75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dea75_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_dea75_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_dea75_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_dea75_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dea75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dea75_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_dea75_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_dea75_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_dea75_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dea75_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_dea75_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_dea75_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_dea75_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dea75_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_dea75_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_dea75_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_dea75_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dea75_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_dea75_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_dea75_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_dea75_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dea75_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_dea75_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_dea75_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_dea75_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dea75_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_dea75_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_dea75_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_dea75_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dea75_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_dea75_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_dea75_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_dea75_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dea75_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_dea75_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_dea75_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_dea75_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dea75_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_dea75_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_dea75_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_dea75_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_dea75_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dea75_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_dea75_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_dea75_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_dea75_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 我们还可以构建一个函数，同时突出显示行、列和 DataFrame 中的最大值。

# %%
def highlight_max(s, props=""):
    return np.where(s == np.nanmax(s.values), props, '')
s2.apply(highlight_max, props='color:white;background-color:darkblue', axis=0)

# s2.apply(highlight_max, props='color:white;background-color:darkblue', axis=0).to_html('test.html')
# Out:
# <style type="text/css">
# #T_b3c93_row0_col2, #T_b3c93_row0_col3, #T_b3c93_row6_col0, #T_b3c93_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_b3c93_row1_col1, #T_b3c93_row4_col3, #T_b3c93_row5_col0, #T_b3c93_row5_col3, #T_b3c93_row6_col1, #T_b3c93_row8_col0, #T_b3c93_row8_col1, #T_b3c93_row8_col2, #T_b3c93_row9_col2, #T_b3c93_row9_col3 {
#   color: red;
# }
# #T_b3c93_row1_col3, #T_b3c93_row2_col0, #T_b3c93_row4_col1, #T_b3c93_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_b3c93_row2_col2, #T_b3c93_row3_col1, #T_b3c93_row6_col2, #T_b3c93_row7_col2, #T_b3c93_row8_col3 {
#   opacity: 20%;
# }
# </style>
# <table id="T_b3c93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3c93_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b3c93_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b3c93_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b3c93_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3c93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3c93_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_b3c93_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_b3c93_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_b3c93_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3c93_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_b3c93_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_b3c93_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_b3c93_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3c93_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_b3c93_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_b3c93_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_b3c93_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3c93_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_b3c93_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_b3c93_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_b3c93_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3c93_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_b3c93_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_b3c93_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_b3c93_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3c93_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_b3c93_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_b3c93_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_b3c93_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3c93_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_b3c93_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_b3c93_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_b3c93_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3c93_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_b3c93_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_b3c93_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_b3c93_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3c93_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_b3c93_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_b3c93_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_b3c93_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3c93_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_b3c93_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_b3c93_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_b3c93_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 我们可以在不同的轴上使用相同的函数，这里用紫色突出显示 `DataFrame` 最大值，用粉色突出显示行最大值。

# %%
(
    s2.apply(highlight_max, props="color:white;background-color:pink;", axis=1).apply(
        highlight_max, props="color:white;background-color:purple;", axis=None
    )
)
# 显示了某些样式如何被其他样式覆盖
# Out:
# <style type="text/css">
# #T_b3c93_row0_col2, #T_b3c93_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_b3c93_row0_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col0, #T_b3c93_row2_col3, #T_b3c93_row3_col0, #T_b3c93_row4_col0, #T_b3c93_row5_col2, #T_b3c93_row7_col0, #T_b3c93_row9_col0 {
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col1, #T_b3c93_row4_col3, #T_b3c93_row5_col0, #T_b3c93_row5_col3, #T_b3c93_row6_col1, #T_b3c93_row8_col0, #T_b3c93_row8_col1, #T_b3c93_row8_col2, #T_b3c93_row9_col2, #T_b3c93_row9_col3 {
#   color: red;
# }
# #T_b3c93_row1_col3, #T_b3c93_row2_col0, #T_b3c93_row4_col1, #T_b3c93_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_b3c93_row2_col2, #T_b3c93_row3_col1, #T_b3c93_row6_col2, #T_b3c93_row7_col2 {
#   opacity: 20%;
# }
# #T_b3c93_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# #T_b3c93_row8_col3 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_level0_row0, #T_b3c93_level0_row1, #T_b3c93_level0_row2, #T_b3c93_level0_row3, #T_b3c93_level0_row4 {
#   color: darkblue;
# }
# #T_b3c93_level0_row5, #T_b3c93_level0_row6, #T_b3c93_level0_row7, #T_b3c93_level0_row8, #T_b3c93_level0_row9 {
#   color: yellow;
# }
# #T_b3c93_level0_col0, #T_b3c93_level0_col1 {
#   color: pink;
# }
# #T_b3c93_level0_col2, #T_b3c93_level0_col3 {
#   color: darkblue;
# }
# </style>
# <table id="T_b3c93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3c93_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b3c93_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b3c93_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b3c93_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3c93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3c93_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_b3c93_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_b3c93_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_b3c93_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3c93_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_b3c93_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_b3c93_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_b3c93_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3c93_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_b3c93_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_b3c93_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_b3c93_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3c93_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_b3c93_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_b3c93_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_b3c93_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3c93_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_b3c93_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_b3c93_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_b3c93_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3c93_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_b3c93_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_b3c93_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_b3c93_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3c93_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_b3c93_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_b3c93_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_b3c93_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3c93_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_b3c93_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_b3c93_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_b3c93_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3c93_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_b3c93_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_b3c93_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_b3c93_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3c93_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_b3c93_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_b3c93_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_b3c93_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 作用于索引和列表头

# %% [markdown]
# 通过使用以下方法可以对标头实现类似的应用：
# - `.map_index()`（按元素）：接受一个函数，该函数采用单个值并返回带有 CSS 属性值对的字符串。
# - `.apply_index()`（按 level）：接受一个函数，该函数接受一个 Series 并返回一个 Series 或具有相同形状的 numpy 数组，其中每个元素都是带有 CSS 属性值对的字符串。此方法一次一次通过索引的每个级别。要设置索引的样式，请使用 `axis=0`，要设置列标题的样式 `axis=1`。

# %% [markdown]
# You can select a `level` of a `MultiIndex` but currently no similar `subset` application is available for these methods.
#
# <div class="alert alert-warning">
#     <strong>警告！</strong>如果你使用的不是 2.X 的 pandas，那么需要使用 applymap_index，而不是 map_index()。
#
# 前面的所有样式都会被应用。
# </div>

# %%
s2
# Out:
# <style type="text/css">
# #T_b3c93_row0_col2, #T_b3c93_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_b3c93_row0_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col0, #T_b3c93_row2_col3, #T_b3c93_row3_col0, #T_b3c93_row4_col0, #T_b3c93_row5_col2, #T_b3c93_row7_col0, #T_b3c93_row9_col0 {
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col1, #T_b3c93_row4_col3, #T_b3c93_row5_col0, #T_b3c93_row5_col3, #T_b3c93_row6_col1, #T_b3c93_row8_col0, #T_b3c93_row8_col1, #T_b3c93_row8_col2, #T_b3c93_row9_col2, #T_b3c93_row9_col3 {
#   color: red;
# }
# #T_b3c93_row1_col3, #T_b3c93_row2_col0, #T_b3c93_row4_col1, #T_b3c93_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_b3c93_row2_col2, #T_b3c93_row3_col1, #T_b3c93_row6_col2, #T_b3c93_row7_col2 {
#   opacity: 20%;
# }
# #T_b3c93_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# #T_b3c93_row8_col3 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_level0_row0, #T_b3c93_level0_row1, #T_b3c93_level0_row2, #T_b3c93_level0_row3, #T_b3c93_level0_row4 {
#   color: darkblue;
# }
# #T_b3c93_level0_row5, #T_b3c93_level0_row6, #T_b3c93_level0_row7, #T_b3c93_level0_row8, #T_b3c93_level0_row9 {
#   color: yellow;
# }
# #T_b3c93_level0_col0, #T_b3c93_level0_col1 {
#   color: pink;
# }
# #T_b3c93_level0_col2, #T_b3c93_level0_col3 {
#   color: darkblue;
# }
# </style>
# <table id="T_b3c93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3c93_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b3c93_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b3c93_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b3c93_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3c93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3c93_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_b3c93_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_b3c93_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_b3c93_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3c93_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_b3c93_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_b3c93_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_b3c93_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3c93_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_b3c93_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_b3c93_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_b3c93_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3c93_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_b3c93_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_b3c93_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_b3c93_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3c93_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_b3c93_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_b3c93_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_b3c93_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3c93_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_b3c93_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_b3c93_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_b3c93_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3c93_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_b3c93_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_b3c93_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_b3c93_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3c93_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_b3c93_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_b3c93_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_b3c93_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3c93_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_b3c93_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_b3c93_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_b3c93_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3c93_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_b3c93_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_b3c93_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_b3c93_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
s2.applymap_index(lambda v: 'color:yellow;' if v > 4 else 'color:darkblue;', axis=0)
# Out:
# <style type="text/css">
# #T_b3c93_row0_col2, #T_b3c93_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_b3c93_row0_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col0, #T_b3c93_row2_col3, #T_b3c93_row3_col0, #T_b3c93_row4_col0, #T_b3c93_row5_col2, #T_b3c93_row7_col0, #T_b3c93_row9_col0 {
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col1, #T_b3c93_row4_col3, #T_b3c93_row5_col0, #T_b3c93_row5_col3, #T_b3c93_row6_col1, #T_b3c93_row8_col0, #T_b3c93_row8_col1, #T_b3c93_row8_col2, #T_b3c93_row9_col2, #T_b3c93_row9_col3 {
#   color: red;
# }
# #T_b3c93_row1_col3, #T_b3c93_row2_col0, #T_b3c93_row4_col1, #T_b3c93_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_b3c93_row2_col2, #T_b3c93_row3_col1, #T_b3c93_row6_col2, #T_b3c93_row7_col2 {
#   opacity: 20%;
# }
# #T_b3c93_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# #T_b3c93_row8_col3 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_level0_row0, #T_b3c93_level0_row1, #T_b3c93_level0_row2, #T_b3c93_level0_row3, #T_b3c93_level0_row4 {
#   color: darkblue;
#   color: darkblue;
# }
# #T_b3c93_level0_row5, #T_b3c93_level0_row6, #T_b3c93_level0_row7, #T_b3c93_level0_row8, #T_b3c93_level0_row9 {
#   color: yellow;
#   color: yellow;
# }
# #T_b3c93_level0_col0, #T_b3c93_level0_col1 {
#   color: pink;
# }
# #T_b3c93_level0_col2, #T_b3c93_level0_col3 {
#   color: darkblue;
# }
# </style>
# <table id="T_b3c93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3c93_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b3c93_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b3c93_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b3c93_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3c93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3c93_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_b3c93_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_b3c93_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_b3c93_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3c93_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_b3c93_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_b3c93_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_b3c93_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3c93_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_b3c93_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_b3c93_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_b3c93_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3c93_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_b3c93_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_b3c93_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_b3c93_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3c93_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_b3c93_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_b3c93_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_b3c93_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3c93_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_b3c93_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_b3c93_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_b3c93_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3c93_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_b3c93_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_b3c93_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_b3c93_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3c93_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_b3c93_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_b3c93_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_b3c93_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3c93_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_b3c93_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_b3c93_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_b3c93_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3c93_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_b3c93_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_b3c93_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_b3c93_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
s2.applymap_index(lambda s: "color:pink;" if s in ["A", "B"] else "color:darkblue;", axis=1)
# Out:
# <style type="text/css">
# #T_b3c93_row0_col2, #T_b3c93_row7_col1 {
#   color: white;
#   background-color: darkblue;
# }
# #T_b3c93_row0_col3 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col0, #T_b3c93_row2_col3, #T_b3c93_row3_col0, #T_b3c93_row4_col0, #T_b3c93_row5_col2, #T_b3c93_row7_col0, #T_b3c93_row9_col0 {
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_row1_col1, #T_b3c93_row4_col3, #T_b3c93_row5_col0, #T_b3c93_row5_col3, #T_b3c93_row6_col1, #T_b3c93_row8_col0, #T_b3c93_row8_col1, #T_b3c93_row8_col2, #T_b3c93_row9_col2, #T_b3c93_row9_col3 {
#   color: red;
# }
# #T_b3c93_row1_col3, #T_b3c93_row2_col0, #T_b3c93_row4_col1, #T_b3c93_row6_col3 {
#   color: red;
#   opacity: 20%;
# }
# #T_b3c93_row2_col2, #T_b3c93_row3_col1, #T_b3c93_row6_col2, #T_b3c93_row7_col2 {
#   opacity: 20%;
# }
# #T_b3c93_row6_col0 {
#   color: white;
#   background-color: darkblue;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: purple;
# }
# #T_b3c93_row8_col3 {
#   opacity: 20%;
#   color: white;
#   background-color: pink;
#   color: white;
#   background-color: pink;
# }
# #T_b3c93_level0_row0, #T_b3c93_level0_row1, #T_b3c93_level0_row2, #T_b3c93_level0_row3, #T_b3c93_level0_row4 {
#   color: darkblue;
#   color: darkblue;
# }
# #T_b3c93_level0_row5, #T_b3c93_level0_row6, #T_b3c93_level0_row7, #T_b3c93_level0_row8, #T_b3c93_level0_row9 {
#   color: yellow;
#   color: yellow;
# }
# #T_b3c93_level0_col0, #T_b3c93_level0_col1 {
#   color: pink;
#   color: pink;
# }
# #T_b3c93_level0_col2, #T_b3c93_level0_col3 {
#   color: darkblue;
#   color: darkblue;
# }
# </style>
# <table id="T_b3c93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3c93_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b3c93_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b3c93_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b3c93_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3c93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3c93_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_b3c93_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_b3c93_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_b3c93_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3c93_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_b3c93_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_b3c93_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_b3c93_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b3c93_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_b3c93_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_b3c93_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_b3c93_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b3c93_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_b3c93_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_b3c93_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_b3c93_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b3c93_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_b3c93_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_b3c93_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_b3c93_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b3c93_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_b3c93_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_b3c93_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_b3c93_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b3c93_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_b3c93_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_b3c93_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_b3c93_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b3c93_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_b3c93_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_b3c93_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_b3c93_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b3c93_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_b3c93_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_b3c93_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_b3c93_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_b3c93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b3c93_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_b3c93_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_b3c93_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_b3c93_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 通过切片进行更精细的控制

# %% [markdown]
# 到目前为止，我们展示的 `Styler.apply` 和 `Styler.map` 函数的示例尚未演示该 `subset` 参数的使用。这是一个有用的参数，它具有很大的灵活性：它允许您将样式应用于特定的行或列，而无需将该逻辑编码到您的 `style` 函数中。

# %% [markdown]
# 传递给 `subset` 的值的行为类似于对 `DataFrame` 进行切片；
# - 标量被视为列标签
# - 列表（或 Series 或 NumPy 数组）被视为多列标签
# - 元组被视为 `(row_indexer, column_indexer)`

# %%
df3 = pd.DataFrame(
    np.random.randn(4, 4),
    pd.MultiIndex.from_product([["A", "B"], ["r1", "r2"]]),
    columns=["c1", "c2", "c3", "c4"],
)
df3
# Out:
#             c1        c2        c3        c4
# A r1 -1.070753  1.054452 -0.403177  1.222445
#   r2  0.208275  0.976639  0.356366  0.706573
# B r1  0.010500  1.785870  0.126912  0.401989
#   r2  1.883151 -1.347759 -1.270485  0.969397

# %%
slice_ = ['c3', 'c4']
(
    df3.style.apply(
        highlight_max, props="color:red;", axis=0, subset=slice_
    ).set_properties(**{"background-color": "#ffffb3"}, subset=slice_)
)
# Out:
# <style type="text/css">
# #T_8e627_row0_col2, #T_8e627_row1_col3, #T_8e627_row2_col2, #T_8e627_row2_col3, #T_8e627_row3_col2, #T_8e627_row3_col3 {
#   background-color: #ffffb3;
# }
# #T_8e627_row0_col3, #T_8e627_row1_col2 {
#   color: red;
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_8e627">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e627_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_8e627_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_8e627_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_8e627_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e627_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_8e627_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_8e627_row0_col0" class="data row0 col0" >-1.070753</td>
#       <td id="T_8e627_row0_col1" class="data row0 col1" >1.054452</td>
#       <td id="T_8e627_row0_col2" class="data row0 col2" >-0.403177</td>
#       <td id="T_8e627_row0_col3" class="data row0 col3" >1.222445</td>
#     </tr>
#     <tr>
#       <th id="T_8e627_level1_row1" class="row_heading level1 row1" >r2</th>
#       <td id="T_8e627_row1_col0" class="data row1 col0" >0.208275</td>
#       <td id="T_8e627_row1_col1" class="data row1 col1" >0.976639</td>
#       <td id="T_8e627_row1_col2" class="data row1 col2" >0.356366</td>
#       <td id="T_8e627_row1_col3" class="data row1 col3" >0.706573</td>
#     </tr>
#     <tr>
#       <th id="T_8e627_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#       <th id="T_8e627_level1_row2" class="row_heading level1 row2" >r1</th>
#       <td id="T_8e627_row2_col0" class="data row2 col0" >0.010500</td>
#       <td id="T_8e627_row2_col1" class="data row2 col1" >1.785870</td>
#       <td id="T_8e627_row2_col2" class="data row2 col2" >0.126912</td>
#       <td id="T_8e627_row2_col3" class="data row2 col3" >0.401989</td>
#     </tr>
#     <tr>
#       <th id="T_8e627_level1_row3" class="row_heading level1 row3" >r2</th>
#       <td id="T_8e627_row3_col0" class="data row3 col0" >1.883151</td>
#       <td id="T_8e627_row3_col1" class="data row3 col1" >-1.347759</td>
#       <td id="T_8e627_row3_col2" class="data row3 col2" >-1.270485</td>
#       <td id="T_8e627_row3_col3" class="data row3 col3" >0.969397</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 如果与 `IndexSlice` 结合使用，那么它可以以更大的灵活性跨两个维度进行索引。

# %%
idx = pd.IndexSlice
slice_ = idx[idx[:, 'r1'], idx['c2':'c4']]
(
    df3.style.apply(
        highlight_max, props="color:red;", axis=0, subset=slice_
    ).set_properties(**{"background-color": "#ffffb3"}, subset=slice_)
)
# Out:
# <style type="text/css">
# #T_ae1d5_row0_col1, #T_ae1d5_row0_col2, #T_ae1d5_row2_col3 {
#   background-color: #ffffb3;
# }
# #T_ae1d5_row0_col3, #T_ae1d5_row2_col1, #T_ae1d5_row2_col2 {
#   color: red;
#   background-color: #ffffb3;
# }
# </style>
# <table id="T_ae1d5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae1d5_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_ae1d5_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_ae1d5_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_ae1d5_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae1d5_level0_row0" class="row_heading level0 row0" rowspan="2">A</th>
#       <th id="T_ae1d5_level1_row0" class="row_heading level1 row0" >r1</th>
#       <td id="T_ae1d5_row0_col0" class="data row0 col0" >-1.070753</td>
#       <td id="T_ae1d5_row0_col1" class="data row0 col1" >1.054452</td>
#       <td id="T_ae1d5_row0_col2" class="data row0 col2" >-0.403177</td>
#       <td id="T_ae1d5_row0_col3" class="data row0 col3" >1.222445</td>
#     </tr>
#     <tr>
#       <th id="T_ae1d5_level1_row1" class="row_heading level1 row1" >r2</th>
#       <td id="T_ae1d5_row1_col0" class="data row1 col0" >0.208275</td>
#       <td id="T_ae1d5_row1_col1" class="data row1 col1" >0.976639</td>
#       <td id="T_ae1d5_row1_col2" class="data row1 col2" >0.356366</td>
#       <td id="T_ae1d5_row1_col3" class="data row1 col3" >0.706573</td>
#     </tr>
#     <tr>
#       <th id="T_ae1d5_level0_row2" class="row_heading level0 row2" rowspan="2">B</th>
#       <th id="T_ae1d5_level1_row2" class="row_heading level1 row2" >r1</th>
#       <td id="T_ae1d5_row2_col0" class="data row2 col0" >0.010500</td>
#       <td id="T_ae1d5_row2_col1" class="data row2 col1" >1.785870</td>
#       <td id="T_ae1d5_row2_col2" class="data row2 col2" >0.126912</td>
#       <td id="T_ae1d5_row2_col3" class="data row2 col3" >0.401989</td>
#     </tr>
#     <tr>
#       <th id="T_ae1d5_level1_row3" class="row_heading level1 row3" >r2</th>
#       <td id="T_ae1d5_row3_col0" class="data row3 col0" >1.883151</td>
#       <td id="T_ae1d5_row3_col1" class="data row3 col1" >-1.347759</td>
#       <td id="T_ae1d5_row3_col2" class="data row3 col2" >-1.270485</td>
#       <td id="T_ae1d5_row3_col3" class="data row3 col3" >0.969397</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 目前仅支持基于标签的切片，不支持位置切片，也不支持可调用切片。

# %% [markdown]
# 如果您的样式函数使用 `subset` 或 `axis` 关键字参数，请考虑将您的函数包装在中 `functools.partial`，部分化该关键字。

# %% [markdown]
# ## 优化
