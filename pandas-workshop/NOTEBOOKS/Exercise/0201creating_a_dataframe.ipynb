# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.DataFrame({
    'time': pd.Series(range(1000)) / 10,
    'measurement': np.sin(2 * np.pi * pd.Series(range(1000)) / 10)
})

# %%
test_data.head()
# Out:
#    time  measurement
# 0   0.0     0.000000
# 1   0.1     0.587785
# 2   0.2     0.951057
# 3   0.3     0.951057
# 4   0.4     0.587785
